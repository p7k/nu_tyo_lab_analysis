# %%
import pandas as pd
from rich.jupyter import display
from swatch import parse

# %%
swatch_cmyk_coated = parse('nu_swatches/NWU Purple Color Palette - CMYK Coated.ase')
pd.DataFrame.from_records(swatch_cmyk_coated[0]['swatches'])
# Out:
#                           name     type  \
# 0            Purple 160 Coated  Process
# 1            Purple 150 Coated  Process
# 2            Purple 140 Coated  Process
# 3            Purple 130 Coated  Process
# 4            Purple 120 Coated  Process
# 5            Purple 110 Coated  Process
# 6   Northwestern Purple Coated  Process
# 7             Purple 90 Coated  Process
# 8             Purple 80 Coated  Process
# 9             Purple 70 Coated  Process
# 10            Purple 60 Coated  Process
# 11            Purple 50 Coated  Process
# 12            Purple 40 Coated  Process
# 13            Purple 30 Coated  Process
# 14            Purple 20 Coated  Process
# 15            Purple 10 Coated  Process
#
#                                                  data
# 0   {'mode': 'CMYK', 'values': [0.8799999952316284...
# 1   {'mode': 'CMYK', 'values': [0.8700000047683716...
# 2   {'mode': 'CMYK', 'values': [0.8600000143051147...
# 3   {'mode': 'CMYK', 'values': [0.8500000238418579...
# 4   {'mode': 'CMYK', 'values': [0.8500000238418579...
# 5   {'mode': 'CMYK', 'values': [0.8500000238418579...
# 6   {'mode': 'CMYK', 'values': [0.8500000238418579...
# 7   {'mode': 'CMYK', 'values': [0.7900000214576721...
# 8   {'mode': 'CMYK', 'values': [0.6800000071525574...
# 9   {'mode': 'CMYK', 'values': [0.5799999833106995...
# 10  {'mode': 'CMYK', 'values': [0.4699999988079071...
# 11  {'mode': 'CMYK', 'values': [0.3799999952316284...
# 12  {'mode': 'CMYK', 'values': [0.3300000131130218...
# 13  {'mode': 'CMYK', 'values': [0.2599999904632568...
# 14  {'mode': 'CMYK', 'values': [0.1800000071525573...
# 15  {'mode': 'CMYK', 'values': [0.0900000035762786...

# %%
swatch_cmyk_uncoated = parse('nu_swatches/NWU Purple Color Palette - CMYK Uncoated.ase')
pd.DataFrame.from_records(swatch_cmyk_uncoated[0]['swatches'])
# Out:
#                             name     type  \
# 0            Purple 160 Uncoated  Process
# 1            Purple 150 Uncoated  Process
# 2            Purple 140 Uncoated  Process
# 3            Purple 130 Uncoated  Process
# 4            Purple 120 Uncoated  Process
# 5            Purple 110 Uncoated  Process
# 6   Northwestern Purple Uncoated  Process
# 7             Purple 90 Uncoated  Process
# 8             Purple 80 Uncoated  Process
# 9             Purple 70 Uncoated  Process
# 10            Purple 60 Uncoated  Process
# 11            Purple 50 Uncoated  Process
# 12            Purple 40 Uncoated  Process
# 13            Purple 30 Uncoated  Process
# 14            Purple 20 Uncoated  Process
# 15            Purple 10 Uncoated  Process
#
#                                                  data
# 0   {'mode': 'CMYK', 'values': [0.8399999737739563...
# 1   {'mode': 'CMYK', 'values': [0.8399999737739563...
# 2   {'mode': 'CMYK', 'values': [0.8399999737739563...
# 3   {'mode': 'CMYK', 'values': [0.8399999737739563...
# 4   {'mode': 'CMYK', 'values': [0.8399999737739563...
# 5   {'mode': 'CMYK', 'values': [0.8399999737739563...
# 6   {'mode': 'CMYK', 'values': [0.8399999737739563...
# 7   {'mode': 'CMYK', 'values': [0.7900000214576721...
# 8   {'mode': 'CMYK', 'values': [0.699999988079071,...
# 9   {'mode': 'CMYK', 'values': [0.6100000143051147...
# 10  {'mode': 'CMYK', 'values': [0.5299999713897705...
# 11  {'mode': 'CMYK', 'values': [0.4499999880790710...
# 12  {'mode': 'CMYK', 'values': [0.3600000143051147...
# 13  {'mode': 'CMYK', 'values': [0.2800000011920929...
# 14  {'mode': 'CMYK', 'values': [0.1800000071525573...
# 15  {'mode': 'CMYK', 'values': [0.1000000014901161...

# %%
swatch_rgb = parse('nu_swatches/NWU Purple Color Palette - RGB.ase')
pd.DataFrame.from_records(swatch_rgb[0]['swatches'])
# Out:
#                        name     type  \
# 0            Purple 160 RGB  Process
# 1            Purple 150 RGB  Process
# 2            Purple 140 RGB  Process
# 3            Purple 130 RGB  Process
# 4            Purple 120 RGB  Process
# 5            Purple 110 RGB  Process
# 6   Northwestern Purple RGB  Process
# 7             Purple 90 RGB  Process
# 8             Purple 80 RGB  Process
# 9             Purple 70 RGB  Process
# 10            Purple 60 RGB  Process
# 11            Purple 50 RGB  Process
# 12            Purple 40 RGB  Process
# 13            Purple 30 RGB  Process
# 14            Purple 20 RGB  Process
# 15            Purple 10 RGB  Process
#
#                                                  data
# 0   {'mode': 'RGB', 'values': [0.11372549086809158...
# 1   {'mode': 'RGB', 'values': [0.14901961386203766...
# 2   {'mode': 'RGB', 'values': [0.1882352977991104,...
# 3   {'mode': 'RGB', 'values': [0.21960784494876862...
# 4   {'mode': 'RGB', 'values': [0.250980406999588, ...
# 5   {'mode': 'RGB', 'values': [0.2823529541492462,...
# 6   {'mode': 'RGB', 'values': [0.30588236451148987...
# 7   {'mode': 'RGB', 'values': [0.35686275362968445...
# 8   {'mode': 'RGB', 'values': [0.40784314274787903...
# 9   {'mode': 'RGB', 'values': [0.4627451002597809,...
# 10  {'mode': 'RGB', 'values': [0.5137255191802979,...
# 11  {'mode': 'RGB', 'values': [0.5764706134796143,...
# 12  {'mode': 'RGB', 'values': [0.6431372761726379,...
# 13  {'mode': 'RGB', 'values': [0.7137255072593689,...
# 14  {'mode': 'RGB', 'values': [0.800000011920929, ...
# 15  {'mode': 'RGB', 'values': [0.8941176533699036,...
